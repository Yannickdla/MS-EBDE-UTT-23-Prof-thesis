# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

from auto_ts import auto_timeseries
from pmdarima.arima import auto_arima,ADFTest
from autots import AutoTS

from sklearn.metrics import mean_absolute_error, mean_squared_error

import warnings

# %% [markdown]
# ## On va essayer de construire un modèle pour chaque famille produit dans ce notebook

# %%
def r2_ajuste(r2,n,p):

    return  1 - (  ((1 - r2) * (n - 1)) / (n - p - 1)  )

def determine_petit_truc(series):
    min_positive_value = series[series > 0].min()
    val = 0.00001
    return min_positive_value * val

# Fonction pour tester la stationnarité avec le test ADF
def test_stationarity(series):
    result = adfuller(series.dropna())
    return result[1]  # Retourne la p-value

# Fonction pour appliquer la transformation logarithmique
def apply_log(series, p):
    return np.log(series + p)

## reconstruction pour un dataframe 
def deDiff(orig, diff,order,log_order):
    dfout = pd.DataFrame(index=orig.index, columns=orig.columns)
    cols = orig.columns

    for family in cols:
        #affectation des premières valeurs 
        dfout[family].iloc[:order] = orig[family].iloc[:order]
        # recontruction du reste
        for i in range(order, len(orig)):
            dfout[family].iloc[i] = dfout[family].iloc[i-order]  +  diff[family].iloc[i-order]
        dfout[family]
        if log_order == 1:
            dfout = np.exp(dfout)
    return dfout
## reconstruction pour une colonne de dataframe 

def deDiffFamily(orig, diff, order,log_order):
    """
    Fonction poure reconstruire les colonnes de dataframes à différenciation
    orig = la colonne originale
    diff = la colonne des valuers différenciées
    order = l'ordre de différentiation de la colone
    log_order = 1 si on a utilisé un logarithme et 0 sinon
    """
    dfout = pd.Series(index=orig.index, dtype=orig.dtype)
    dfout.iloc[:order] = orig.iloc[:order]
    for i in range(order, len(orig)):
        dfout.iloc[i] = dfout.iloc[i-order] + diff.iloc[i-order]
    if log_order == 1:
        dfout = np.exp(dfout)
    return dfout

# %% [markdown]
# ## Chargement des données

# %%
# Charger les données des séries différenciées à partir d'un fichier CSV
df_differentiated = pd.read_csv('series_differenciees.csv')
df_transfo = pd.read_csv('transformations_appliquees.csv')
df_transfo.set_index('Famille', inplace=True)

# %% [markdown]
# ## Auto arima pour trouver le meilleur modèle

# %%
# Ignorer les avertissements liés à l'auto-ARIMA pour garder le code propre
warnings.filterwarnings("ignore")

best_models = {}
      #  transfo_family = dictTransformations.loc[family]
      #  diff_order = transfo_family['ordreP']  
# Parcourir chaque colonne (chaque série temporelle)

for col in df_differentiated.columns:
    print(f"Processing series: {col}")
    series = df_differentiated[col].dropna()  # Supprimer les éventuels NaN
    diff_fam = df_transfo.loc[col]
    # Appliquer l'auto-ARIMA pour trouver le meilleur modèle
    model = auto_arima(
        series,
        start_p=1,
        start_q=1,
        max_p=5, 
        max_q=5,
        d = int(diff_fam['Différenciations']) ,
        seasonal=False,  # Modèle non saisonnier
        error_action='warn',
        stepwise=True,  # Méthode plus rapide en recherchant de manière itérative
        trace=True  # Afficher le processus de sélection du modèle
    )
    best_models[col] = model

# Affichage des modèles trouvés
for col, model in best_models.items():
    print(f"\nBest model for {col}:")
    print(model.summary())
# Out:
# Processing series: A
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1423.554, Time=0.08 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1520.395, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1461.448, Time=0.00 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1480.065, Time=0.02 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1518.438, Time=0.00 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=1387.848, Time=0.02 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=1411.114, Time=0.01 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=1387.935, Time=0.09 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=1385.180, Time=0.10 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=1416.249, Time=0.05 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=1378.658, Time=0.12 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=1336.529, Time=0.17 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=1348.876, Time=0.12 sec
#  ARIMA(5,2,2)(0,0,0)[0] intercept   : AIC=1338.515, Time=0.28 sec
#  ARIMA(4,2,3)(0,0,0)[0] intercept   : AIC=1333.918, Time=0.15 sec
#  ARIMA(3,2,3)(0,0,0)[0] intercept   : AIC=1360.801, Time=0.15 sec
#  ARIMA(5,2,3)(0,0,0)[0] intercept   : AIC=1332.976, Time=0.17 sec
#  ARIMA(5,2,4)(0,0,0)[0] intercept   : AIC=1335.560, Time=0.38 sec
#  ARIMA(4,2,4)(0,0,0)[0] intercept   : AIC=1336.828, Time=0.22 sec
#  ARIMA(5,2,3)(0,0,0)[0]             : AIC=1327.508, Time=0.35 sec
#  ARIMA(4,2,3)(0,0,0)[0]             : AIC=1327.178, Time=0.17 sec
#  ARIMA(3,2,3)(0,0,0)[0]             : AIC=1357.774, Time=0.14 sec
#  ARIMA(4,2,2)(0,0,0)[0]             : AIC=1331.342, Time=0.16 sec
#  ARIMA(4,2,4)(0,0,0)[0]             : AIC=1324.102, Time=0.26 sec
#  ARIMA(3,2,4)(0,0,0)[0]             : AIC=1354.332, Time=0.08 sec
#  ARIMA(5,2,4)(0,0,0)[0]             : AIC=1326.854, Time=0.28 sec
#  ARIMA(4,2,5)(0,0,0)[0]             : AIC=inf, Time=0.39 sec
#  ARIMA(3,2,5)(0,0,0)[0]             : AIC=1329.879, Time=0.33 sec
#  ARIMA(5,2,5)(0,0,0)[0]             : AIC=inf, Time=0.39 sec
#
# Best model:  ARIMA(4,2,4)(0,0,0)[0]
# Total fit time: 4.687 seconds
# Processing series: B
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1347.485, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1417.219, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1375.690, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1404.596, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1346.514, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1360.661, Time=0.02 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1347.946, Time=0.06 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1344.416, Time=0.15 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1344.334, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1399.527, Time=0.02 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1345.575, Time=0.07 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1401.679, Time=0.04 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1346.654, Time=0.24 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1348.792, Time=0.04 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 0.787 seconds
# Processing series: C
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1320.205, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1377.992, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1349.448, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1368.713, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1315.895, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1327.055, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1317.617, Time=0.10 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1315.451, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1317.784, Time=0.03 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1317.400, Time=0.12 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.18 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1316.223, Time=0.15 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=inf, Time=0.22 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1309.889, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1308.725, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=1307.486, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1306.374, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1308.119, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1306.593, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1304.883, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1306.513, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1308.450, Time=0.06 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 1.319 seconds
# Processing series: D
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1382.906, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1429.445, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1406.596, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1421.059, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1383.391, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1382.546, Time=0.08 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1415.748, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1382.975, Time=0.12 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1385.142, Time=0.08 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1415.905, Time=0.03 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1384.733, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1376.351, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=1375.302, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1373.336, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1372.993, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1373.050, Time=0.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1375.151, Time=0.02 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.658 seconds
# Processing series: E
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1478.960, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1499.075, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1497.319, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1498.187, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1474.637, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1499.986, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1474.079, Time=0.05 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1491.775, Time=0.02 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1474.403, Time=0.10 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1491.029, Time=0.06 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=1467.825, Time=0.03 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=1465.874, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=1469.803, Time=0.03 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=1469.168, Time=0.02 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1467.691, Time=0.03 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=1471.051, Time=0.07 sec
#
# Best model:  ARIMA(0,0,3)(0,0,0)[0] intercept
# Total fit time: 1.168 seconds
# Processing series: F
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1555.421, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1616.304, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1594.466, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1614.314, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1543.354, Time=0.07 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1572.622, Time=0.03 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1541.581, Time=0.10 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1558.876, Time=0.05 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=1538.067, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=1547.627, Time=0.04 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=1543.748, Time=0.08 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=1536.803, Time=0.17 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1540.635, Time=0.07 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=1538.223, Time=0.28 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=1544.912, Time=0.18 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=1533.827, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1533.642, Time=0.15 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1534.200, Time=0.08 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1539.388, Time=0.08 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1541.141, Time=0.04 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=1531.812, Time=0.18 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1533.576, Time=0.08 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=inf, Time=0.27 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1543.935, Time=0.03 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=inf, Time=0.17 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=inf, Time=0.22 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 3.502 seconds
# Processing series: G
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1245.150, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1314.114, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1269.945, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1297.179, Time=0.00 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1246.641, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1246.323, Time=0.08 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1291.891, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1262.697, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1248.071, Time=0.22 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1240.947, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1238.555, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1236.803, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1239.093, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.632 seconds
# Processing series: H
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1203.422, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1264.190, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1228.906, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1220.739, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1262.213, Time=0.00 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1203.767, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1200.975, Time=0.29 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1205.712, Time=0.21 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1207.233, Time=0.15 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1211.241, Time=0.08 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1221.760, Time=0.06 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1199.758, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1201.930, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1205.227, Time=0.03 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1200.325, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1215.180, Time=0.02 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1214.992, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1202.363, Time=0.02 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=inf, Time=0.57 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 2.198 seconds
# Processing series: I
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1072.071, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1071.261, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1072.462, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1072.681, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1074.439, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1066.530, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1064.522, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1066.617, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1068.557, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.209 seconds
# Processing series: J
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1390.703, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1430.698, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1404.332, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1419.134, Time=0.01 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1392.636, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1392.880, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1418.563, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1398.243, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1393.715, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1393.690, Time=0.00 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.309 seconds
# Processing series: K
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1147.051, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1207.316, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1171.990, Time=0.00 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1166.735, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1205.326, Time=0.00 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1145.274, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1160.424, Time=0.02 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1143.474, Time=0.02 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1150.627, Time=0.03 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=1141.909, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=1141.687, Time=0.01 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=1141.644, Time=0.06 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=1143.412, Time=0.07 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=1139.804, Time=0.03 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=1139.818, Time=0.02 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=1138.446, Time=0.08 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=1138.230, Time=0.12 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1139.449, Time=0.04 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=1140.079, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=1148.765, Time=0.02 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1139.129, Time=0.08 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=1140.805, Time=0.12 sec
#
# Best model:  ARIMA(4,1,1)(0,0,0)[0]
# Total fit time: 0.954 seconds
# Processing series: L
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=839.179, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=838.726, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=839.164, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=839.988, Time=0.00 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=835.150, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=836.801, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=836.911, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=838.807, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.148 seconds
# Processing series: M
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1301.608, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1364.601, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1333.220, Time=0.00 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1318.807, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1362.618, Time=0.00 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1297.800, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1315.505, Time=0.03 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1298.931, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1296.993, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1306.126, Time=0.09 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1297.450, Time=0.10 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1297.472, Time=0.14 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1312.696, Time=0.03 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=1297.391, Time=0.15 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1294.636, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1304.312, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1296.121, Time=0.02 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1295.512, Time=0.03 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=1295.583, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1299.943, Time=0.02 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1310.629, Time=0.03 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1297.298, Time=0.04 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=1295.092, Time=0.13 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 1.364 seconds
# Processing series: N
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=500.533, Time=0.00 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=436.081, Time=0.00 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=498.535, Time=0.00 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=405.253, Time=0.02 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=395.017, Time=0.05 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=384.659, Time=0.08 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=380.648, Time=0.07 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(5,2,0)(0,0,0)[0]             : AIC=378.720, Time=0.05 sec
#  ARIMA(4,2,0)(0,0,0)[0]             : AIC=382.738, Time=0.05 sec
#  ARIMA(5,2,1)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(4,2,1)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(5,2,0)(0,0,0)[0]
# Total fit time: 1.203 seconds
# Processing series: O
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1267.739, Time=0.01 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1375.615, Time=0.03 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1309.502, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1332.585, Time=0.03 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1373.658, Time=0.00 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=1246.312, Time=0.13 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=1269.219, Time=0.00 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=1246.037, Time=0.07 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=1264.629, Time=0.04 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=1223.214, Time=0.25 sec
#  ARIMA(4,2,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=1209.099, Time=0.10 sec
#  ARIMA(5,2,0)(0,0,0)[0] intercept   : AIC=1227.204, Time=0.07 sec
#  ARIMA(5,2,2)(0,0,0)[0] intercept   : AIC=1190.192, Time=0.11 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=1190.101, Time=0.13 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(4,2,3)(0,0,0)[0] intercept   : AIC=1208.940, Time=0.32 sec
#  ARIMA(3,2,3)(0,0,0)[0] intercept   : AIC=1237.664, Time=0.08 sec
#  ARIMA(5,2,3)(0,0,0)[0] intercept   : AIC=1204.568, Time=0.33 sec
#  ARIMA(4,2,2)(0,0,0)[0]             : AIC=1185.698, Time=0.22 sec
#  ARIMA(3,2,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(4,2,1)(0,0,0)[0]             : AIC=1221.066, Time=0.27 sec
#  ARIMA(5,2,2)(0,0,0)[0]             : AIC=1185.557, Time=0.15 sec
#  ARIMA(5,2,1)(0,0,0)[0]             : AIC=1207.070, Time=0.13 sec
#  ARIMA(5,2,3)(0,0,0)[0]             : AIC=1199.545, Time=0.22 sec
#  ARIMA(4,2,3)(0,0,0)[0]             : AIC=1198.104, Time=0.12 sec
#
# Best model:  ARIMA(5,2,2)(0,0,0)[0]
# Total fit time: 3.597 seconds
# Processing series: P
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=230.590, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=226.073, Time=0.00 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=228.601, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=221.314, Time=0.02 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=223.302, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=219.331, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=224.109, Time=0.00 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=221.319, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=212.703, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=211.070, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=211.089, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=212.301, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=210.643, Time=0.05 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=212.322, Time=0.03 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=214.292, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 1.433 seconds
# Processing series: Q
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=650.636, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=646.636, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=648.636, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=648.636, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=647.626, Time=0.00 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.034 seconds
#
# Best model for A:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(4, 2, 4)   Log Likelihood                -653.051
# Date:                Wed, 21 Aug 2024   AIC                           1324.102
# Time:                        09:30:37   BIC                           1341.128
# Sample:                             0   HQIC                          1330.562
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.7325      0.235     -7.374      0.000      -2.193      -1.272
# ar.L2         -1.6204      0.443     -3.654      0.000      -2.489      -0.751
# ar.L3         -1.1309      0.400     -2.826      0.005      -1.915      -0.347
# ar.L4         -0.5895      0.163     -3.611      0.000      -0.909      -0.270
# ma.L1         -1.7093      0.419     -4.082      0.000      -2.530      -0.889
# ma.L2          0.2854      0.706      0.404      0.686      -1.099       1.670
# ma.L3          0.6481      0.738      0.878      0.380      -0.799       2.095
# ma.L4         -0.2128      0.396     -0.537      0.591      -0.990       0.564
# sigma2       2.16e+10   3.81e-11   5.67e+20      0.000    2.16e+10    2.16e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):                 3.98
# Prob(Q):                              0.64   Prob(JB):                         0.14
# Heteroskedasticity (H):               0.45   Skew:                            -0.68
# Prob(H) (two-sided):                  0.12   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.36e+36. Standard errors may be unstable.
#
# Best model for B:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                -668.167
# Date:                Wed, 21 Aug 2024   AIC                           1344.334
# Time:                        09:30:37   BIC                           1352.062
# Sample:                             0   HQIC                          1347.287
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9970      0.011     94.087      0.000       0.976       1.018
# ma.L1         -1.1977      0.179     -6.680      0.000      -1.549      -0.846
# ma.L2          0.3425      0.197      1.740      0.082      -0.043       0.728
# sigma2      1.634e+10    2.3e-12   7.12e+21      0.000    1.63e+10    1.63e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.31
# Prob(Q):                              0.78   Prob(JB):                         0.86
# Heteroskedasticity (H):               1.27   Skew:                             0.14
# Prob(H) (two-sided):                  0.63   Kurtosis:                         2.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.15e+39. Standard errors may be unstable.
#
# Best model for C:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -649.441
# Date:                Wed, 21 Aug 2024   AIC                           1304.883
# Time:                        09:30:37   BIC                           1310.678
# Sample:                             0   HQIC                          1307.097
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2.002e+05      2e+04     10.030      0.000    1.61e+05    2.39e+05
# ar.L1         -0.3146      0.114     -2.765      0.006      -0.538      -0.092
# sigma2      6.851e+09      0.001    4.7e+12      0.000    6.85e+09    6.85e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 1.07
# Prob(Q):                              0.86   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.41   Skew:                             0.35
# Prob(H) (two-sided):                  0.08   Kurtosis:                         2.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.7e+29. Standard errors may be unstable.
#
# Best model for D:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:                        SARIMAX   Log Likelihood                -684.496
# Date:                Wed, 21 Aug 2024   AIC                           1372.993
# Time:                        09:30:37   BIC                           1376.857
# Sample:                             0   HQIC                          1374.469
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    2.39e+05   2.76e+04      8.673      0.000    1.85e+05    2.93e+05
# sigma2      2.663e+10   5.49e+09      4.848      0.000    1.59e+10    3.74e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.99   Jarque-Bera (JB):                 8.12
# Prob(Q):                              0.16   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.64   Skew:                             0.92
# Prob(H) (two-sided):                  0.37   Kurtosis:                         3.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Best model for E:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(0, 0, 3)   Log Likelihood                -727.937
# Date:                Wed, 21 Aug 2024   AIC                           1465.874
# Time:                        09:30:37   BIC                           1475.533
# Sample:                             0   HQIC                          1469.565
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    3.66e+05   3.04e+04     12.041      0.000    3.06e+05    4.26e+05
# ma.L1         -0.4128      0.136     -3.033      0.002      -0.680      -0.146
# ma.L2         -0.2147      0.149     -1.442      0.149      -0.507       0.077
# ma.L3          0.2960      0.126      2.342      0.019       0.048       0.544
# sigma2      1.137e+11      0.032   3.54e+12      0.000    1.14e+11    1.14e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.64
# Prob(Q):                              0.99   Prob(JB):                         0.27
# Heteroskedasticity (H):               0.53   Skew:                             0.55
# Prob(H) (two-sided):                  0.20   Kurtosis:                         3.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.13e+27. Standard errors may be unstable.
#
# Best model for F:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(2, 1, 3)   Log Likelihood                -759.906
# Date:                Wed, 21 Aug 2024   AIC                           1531.812
# Time:                        09:30:37   BIC                           1543.284
# Sample:                             0   HQIC                          1536.180
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9734      0.210     -4.635      0.000      -1.385      -0.562
# ar.L2         -0.3009      0.169     -1.778      0.075      -0.632       0.031
# ma.L1         -1.0857      0.356     -3.047      0.002      -1.784      -0.387
# ma.L2         -0.5736      0.489     -1.172      0.241      -1.533       0.386
# ma.L3          0.7969      0.316      2.519      0.012       0.177       1.417
# sigma2      8.885e+11   4.96e-13   1.79e+24      0.000    8.88e+11    8.88e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                 1.84
# Prob(Q):                              0.72   Prob(JB):                         0.40
# Heteroskedasticity (H):               0.72   Skew:                             0.46
# Prob(H) (two-sided):                  0.51   Kurtosis:                         2.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.27e+40. Standard errors may be unstable.
#
# Best model for G:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:                        SARIMAX   Log Likelihood                -616.401
# Date:                Wed, 21 Aug 2024   AIC                           1236.803
# Time:                        09:30:37   BIC                           1240.666
# Sample:                             0   HQIC                          1238.279
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   8.298e+04   6724.326     12.340      0.000    6.98e+04    9.62e+04
# sigma2      1.843e+09   3.83e+08      4.809      0.000    1.09e+09    2.59e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.47   Jarque-Bera (JB):                 4.03
# Prob(Q):                              0.49   Prob(JB):                         0.13
# Heteroskedasticity (H):               0.48   Skew:                             0.67
# Prob(H) (two-sided):                  0.14   Kurtosis:                         3.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Best model for H:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(1, 1, 2)   Log Likelihood                -595.879
# Date:                Wed, 21 Aug 2024   AIC                           1199.758
# Time:                        09:30:37   BIC                           1207.406
# Sample:                             0   HQIC                          1202.671
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1139      0.269      0.423      0.672      -0.414       0.642
# ma.L1         -1.9131      0.289     -6.609      0.000      -2.480      -1.346
# ma.L2          0.9295      0.302      3.079      0.002       0.338       1.521
# sigma2      1.705e+09   1.37e-10   1.25e+19      0.000    1.71e+09    1.71e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 0.41
# Prob(Q):                              0.63   Prob(JB):                         0.82
# Heteroskedasticity (H):               2.60   Skew:                             0.09
# Prob(H) (two-sided):                  0.06   Kurtosis:                         2.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.7e+35. Standard errors may be unstable.
#
# Best model for I:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:                        SARIMAX   Log Likelihood                -530.261
# Date:                Wed, 21 Aug 2024   AIC                           1064.522
# Time:                        09:30:37   BIC                           1068.386
# Sample:                             0   HQIC                          1065.999
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3598.1529   2637.274      1.364      0.172   -1570.809    8767.115
# sigma2      6.288e+07   7.78e+06      8.079      0.000    4.76e+07    7.81e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1737.44
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.08   Skew:                             4.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Best model for J:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                -692.351
# Date:                Wed, 21 Aug 2024   AIC                           1390.703
# Time:                        09:30:37   BIC                           1396.498
# Sample:                             0   HQIC                          1392.918
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9807      0.034     28.839      0.000       0.914       1.047
# ma.L1         -0.7735      0.120     -6.426      0.000      -1.009      -0.538
# sigma2      3.983e+10   3.13e-13   1.27e+23      0.000    3.98e+10    3.98e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                 7.16
# Prob(Q):                              0.67   Prob(JB):                         0.03
# Heteroskedasticity (H):              11.87   Skew:                             0.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.21e+39. Standard errors may be unstable.
#
# Best model for K:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(4, 1, 1)   Log Likelihood                -563.115
# Date:                Wed, 21 Aug 2024   AIC                           1138.230
# Time:                        09:30:37   BIC                           1149.702
# Sample:                             0   HQIC                          1142.598
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7925      0.258     -3.073      0.002      -1.298      -0.287
# ar.L2         -0.4829      0.249     -1.939      0.053      -0.971       0.005
# ar.L3         -0.3714      0.406     -0.915      0.360      -1.167       0.424
# ar.L4         -0.0653      0.211     -0.309      0.757      -0.479       0.349
# ma.L1         -0.9561      0.118     -8.068      0.000      -1.188      -0.724
# sigma2      4.051e+08   5.56e-10   7.28e+17      0.000    4.05e+08    4.05e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                18.65
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):              45.18   Skew:                            -0.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.12e+33. Standard errors may be unstable.
#
# Best model for L:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:                        SARIMAX   Log Likelihood                -415.575
# Date:                Wed, 21 Aug 2024   AIC                            835.150
# Time:                        09:30:37   BIC                            839.014
# Sample:                             0   HQIC                           836.627
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    284.4314    352.839      0.806      0.420    -407.120     975.982
# sigma2      7.002e+05   1.73e+05      4.040      0.000    3.61e+05    1.04e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):               283.96
# Prob(Q):                              0.63   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.86   Skew:                             3.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Best model for M:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                -642.318
# Date:                Wed, 21 Aug 2024   AIC                           1294.636
# Time:                        09:30:37   BIC                           1304.197
# Sample:                             0   HQIC                          1298.277
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.4431      0.276     -5.227      0.000      -1.984      -0.902
# ar.L2         -0.6999      0.193     -3.636      0.000      -1.077      -0.323
# ma.L1         -0.0873      0.350     -0.249      0.803      -0.773       0.599
# ma.L2         -0.8372      0.299     -2.802      0.005      -1.423      -0.252
# sigma2      1.262e+10   2.14e-11   5.91e+20      0.000    1.26e+10    1.26e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):                21.67
# Prob(Q):                              0.61   Prob(JB):                         0.00
# Heteroskedasticity (H):                inf   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.82e+36. Standard errors may be unstable.
#
# Best model for N:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(5, 2, 0)   Log Likelihood                -183.360
# Date:                Wed, 21 Aug 2024   AIC                            378.720
# Time:                        09:30:37   BIC                            390.071
# Sample:                             0   HQIC                           383.027
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -2.2039      0.121    -18.282      0.000      -2.440      -1.968
# ar.L2         -2.5495      0.255     -9.983      0.000      -3.050      -2.049
# ar.L3         -2.1053      0.320     -6.584      0.000      -2.732      -1.479
# ar.L4         -1.2611      0.310     -4.068      0.000      -1.869      -0.654
# ar.L5         -0.3796      0.153     -2.477      0.013      -0.680      -0.079
# sigma2        93.3839     16.107      5.798      0.000      61.814     124.953
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.17   Jarque-Bera (JB):                18.48
# Prob(Q):                              0.28   Prob(JB):                         0.00
# Heteroskedasticity (H):                inf   Skew:                            -0.90
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Best model for O:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(5, 2, 2)   Log Likelihood                -584.779
# Date:                Wed, 21 Aug 2024   AIC                           1185.557
# Time:                        09:30:37   BIC                           1200.692
# Sample:                             0   HQIC                          1191.299
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.8048      0.443     -4.072      0.000      -2.673      -0.936
# ar.L2         -1.9083      0.839     -2.275      0.023      -3.552      -0.264
# ar.L3         -1.7309      0.944     -1.834      0.067      -3.581       0.119
# ar.L4         -1.2648      0.822     -1.538      0.124      -2.876       0.347
# ar.L5         -0.3965      0.518     -0.765      0.444      -1.412       0.619
# ma.L1         -1.8503      0.456     -4.059      0.000      -2.744      -0.957
# ma.L2          0.8805      0.566      1.555      0.120      -0.229       1.990
# sigma2      1.893e+09   8.92e-10   2.12e+18      0.000    1.89e+09    1.89e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.08   Jarque-Bera (JB):                50.83
# Prob(Q):                              0.30   Prob(JB):                         0.00
# Heteroskedasticity (H):                inf   Skew:                             1.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.56e+36. Standard errors may be unstable.
#
# Best model for P:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -102.322
# Date:                Wed, 21 Aug 2024   AIC                            210.643
# Time:                        09:30:37   BIC                            216.379
# Sample:                             0   HQIC                           212.828
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7050      0.340     -2.071      0.038      -1.372      -0.038
# ma.L2         -0.2436      0.241     -1.011      0.312      -0.716       0.229
# sigma2         3.3608      0.185     18.173      0.000       2.998       3.723
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):              1742.10
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):                inf   Skew:                             4.65
# Prob(H) (two-sided):                  0.00   Kurtosis:                        30.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Best model for Q:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   51
# Model:                        SARIMAX   Log Likelihood                -322.318
# Date:                Wed, 21 Aug 2024   AIC                            646.636
# Time:                        09:30:37   BIC                            648.568
# Sample:                             0   HQIC                           647.374
#                                  - 51
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.807e+04    715.702     25.249      0.000    1.67e+04    1.95e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              4908.58
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):                inf   Skew:                             6.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                        49.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## Calcul des métriques pour le baseline model
#
# #### SMAPE : Symetric Mean Absolute Percentage Error
# #### Adjusted SMAPE : Adjusted Symmetric Mean Absolute Percentage Error
# #### MAPE : Mean Absolute Percentage Error
# #### MAAPE : Mean Arctangent Absolute Percentage Error

# %%
# Fonction pour calculer SMAPE
def smape(y_true, y_pred):
    smape_val = 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))
    return smape_val

# Fonction pour calculer l'Adjusted SMAPE (ASMAPE)
def adjusted_smape(y_true, y_pred):
    adjsmape = 1/y_true.size  * np.sum( np.abs(y_pred - y_true) / ( np.abs(y_true) + np.abs(y_pred) )*100 )
    oldadjsmape = 100 * np.mean(np.abs(y_pred - y_true) / (0.5 * (np.abs(y_true) + np.abs(y_pred))))
    return adjsmape
# Fonction pour calculer le MAAPE
def maape(actual, forecast):
    maape = np.mean(np.arctan(np.abs((actual - forecast) / actual))) * (180/np.pi)
    return maape

# Créer un dictionnaire pour stocker les métriques
metrics = {}

# Parcourir chaque modèle ajusté
for col, model in best_models.items():
    # Obtenir la série originale (sans NaN)
    series = df_differentiated[col].dropna()
    n = 3
    # Diviser les données
    train = series.iloc[:-n]
    test = series.iloc[-n:]

    # Réajuster le modèle sur l'ensemble d'entraînement
    model.fit(train)
    
    # Faire des prévisions sur l'ensemble de test
    predictions = model.predict(n_periods=len(test))
    
    # Calculer les métriques
    mape = np.mean(np.abs((test - predictions) / test)) * 100
    maape_value = maape(test, predictions)
    smape_value = smape(test, predictions)
    asmape_value = adjusted_smape(test, predictions)
    
    # Enregistrer les métriques
    metrics[col] = {
        "MAAPE": maape_value,
        "MAPE": mape,
        "SMAPE": smape_value,
        "ASMAPE": asmape_value
    }

# Afficher les métriques pour chaque série
for col, metric in metrics.items():
    print(f"\nMetrics for {col}:")
    print(f"MAAPE: {metric['MAAPE']}°")
    print(f"MAPE: {metric['MAPE']}%")
    print(f"SMAPE: {metric['SMAPE']}%")
    print(f"ASMAPE: {metric['ASMAPE']}%")
# Out:
# Metrics for A:
# MAAPE: 56.363685758427806°
# MAPE: 163.1070670390797%
# SMAPE: 87.2694121936747%
# ASMAPE: 43.63470609683735%
#
# Metrics for B:
# MAAPE: 26.232453911064557°
# MAPE: 57.886483607682905%
# SMAPE: 44.547599187713246%
# ASMAPE: 22.273799593856626%
#
# Metrics for C:
# MAAPE: 27.570885599567525°
# MAPE: 52.37269554344234%
# SMAPE: 48.43809698201678%
# ASMAPE: 24.219048491008394%
#
# Metrics for D:
# MAAPE: 70.82965889278489°
# MAPE: 1420.720772546767%
# SMAPE: 140.29328114039316%
# ASMAPE: 70.14664057019658%
#
# Metrics for E:
# MAAPE: 40.304589767189896°
# MAPE: inf%
# SMAPE: 94.35229898102273%
# ASMAPE: 47.176149490511364%
#
# Metrics for F:
# MAAPE: 45.93497352530506°
# MAPE: 111.1697920540745%
# SMAPE: 157.59124196592848%
# ASMAPE: 78.79562098296424%
#
# Metrics for G:
# MAAPE: 25.059221604454795°
# MAPE: 49.65309884675395%
# SMAPE: 39.168751368881935%
# ASMAPE: 19.584375684440964%
#
# Metrics for H:
# MAAPE: 24.040978900125875°
# MAPE: 49.19161649206387%
# SMAPE: 83.12882311103554%
# ASMAPE: 41.564411555517765%
#
# Metrics for I:
# MAAPE: 42.00379561058955°
# MAPE: 203.54473881730297%
# SMAPE: 110.20486689796971%
# ASMAPE: 55.10243344898485%
#
# Metrics for J:
# MAAPE: 39.93548458980362°
# MAPE: 265.8500080339571%
# SMAPE: 72.82131278934271%
# ASMAPE: 36.410656394671356%
#
# Metrics for K:
# MAAPE: 20.9977084625287°
# MAPE: 40.097500097007696%
# SMAPE: 55.25620312314852%
# ASMAPE: 27.628101561574255%
#
# Metrics for L:
# MAAPE: 54.70178181833914°
# MAPE: inf%
# SMAPE: 154.91761355365344%
# ASMAPE: 77.45880677682672%
#
# Metrics for M:
# MAAPE: 27.17090790329445°
# MAPE: 59.61319439087772%
# SMAPE: 42.964747381288724%
# ASMAPE: 21.482373690644366%
#
# Metrics for N:
# MAAPE: 83.16262144981788°
# MAPE: inf%
# SMAPE: 200.0%
# ASMAPE: 100.0%
#
# Metrics for O:
# MAAPE: 58.665323519049714°
# MAPE: 257.3940271681861%
# SMAPE: 164.13203771086907%
# ASMAPE: 82.06601885543454%
#
# Metrics for P:
# MAAPE: 38.148993958407104°
# MAPE: 80.04968854452876%
# SMAPE: 137.34050364895182%
# ASMAPE: 68.67025182447593%
#
# Metrics for Q:
# MAAPE: 45.0°
# MAPE: 100.0%
# SMAPE: 200.0%
# ASMAPE: 33.33333333333333%
